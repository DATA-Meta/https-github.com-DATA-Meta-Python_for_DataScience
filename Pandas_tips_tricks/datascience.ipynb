# %%
Array = [80, 85, 90, 100, 105, 110, 120, 125]
print(Array)
# Out:
# [80, 85, 90, 100, 105, 110, 120, 125]

# %%
import pandas as pd 
d = {'col1' : [1, 2, 3, 4, 7], 'col2' : [4, 5, 6, 9, 5], 'col3' : [7, 8, 12, 1, 11]}
df = pd.DataFrame(data=d)
print(df)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11

# %%
# df.shape
print(df.shape[1])
df.shape[0]
# Out:
# 3
# 5

# %%
Average_pulse_max = max(80, 85, 90, 95, 100, 105, 110, 115, 120, 125)
print(Average_pulse_max)
# Out:
# 125

# %%
Average_pulse_min = min(80, 85, 90, 95, 100, 105, 110, 115, 120, 125)
print(Average_pulse_min)
# Out:
# 80

# %%
import numpy as np 
Calorie_burnage = [240, 250, 260, 270, 280, 290, 300, 310, 320, 330]
average_calorie_burnage = np.mean(Calorie_burnage)
print(average_calorie_burnage)
# Out:
# 285.0

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\usman\.conda\envs\python_eda\lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
url = "https://www.w3schools.com/datascience/ds_analyze_data.asp"
health_data = pd.read_html(url)

print(f"Number of tables found: {len(health_data)}")
print(health_data[0])
# Out:
# Number of tables found: 1
#   Unnamed: 0  Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0      Count     10.00          10.00      10.00            10.00       10.00
# 1       Mean     51.00         102.50     137.00           285.00        6.60
# 2        Std     10.49          15.40      11.35            30.28        3.63
# 3        Min     30.00          80.00     120.00           240.00        0.00
# 4        25%     45.00          91.25     130.00           262.50        7.00
# 5        50%     52.50         102.50     140.00           285.00        8.00
# 6        75%     60.00         113.75     145.00           307.50        8.00
# 7        Max     60.00         125.00     150.00           330.00       10.00
#
#    Hours_Sleep
# 0        10.00
# 1         7.50
# 2         0.53
# 3         7.00
# 4         7.00
# 5         7.50
# 6         8.00
# 7         8.00

# %%
print(health_data.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(health_data.head())
#
# AttributeError: 'list' object has no attribute 'head'
